# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv()
model = init_chat_model(
  model="openai/gpt-oss-120b",
  model_provider="groq"
)

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool(description="search the web for latest information")
def web_search(query: str) -> Dict[str, Any]:
  return tavily_client.search(query)

# %%
from langchain.agents import create_agent

agent = create_agent(
  model=model,
  tools=[web_search]
)

# %%
from langchain.messages import HumanMessage

userInput = input("Ask anything: ")

query = HumanMessage(content=userInput)

response = agent.invoke(
  {"messages":[query]}
)

print(response["messages"][-1].content)
# Out:
# **Current time in Goa (as of the moment you asked)**
# - **Local time:** ≈ 05:30 AM IST (Indian Standard Time) on **Tuesday, 5 July 2026**
# - **UTC offset:** + 05:30
#
# *(IST does not observe daylight‑saving time, so the offset stays the same year‑round.)*
#
# ---
#
# ## Is now a good time to visit Goa?
#
# ### Weather & Season
# | Month | Typical Weather in Goa | Tourist vibe |
# |-------|------------------------|--------------|
# | **Nov – Feb** | Cool‑dry (24‑30 °C), low humidity, clear skies | Peak season – beaches are bustling, prices highest |
# | **Mar – May** | Hot & dry (30‑35 °C), occasional pre‑monsoon showers | Shoulder season – fewer crowds, but very hot |
# | **Jun – Sep** | **Monsoon** (heavy rain, 80‑95 % humidity, 24‑30 °C) | Low season – lush green landscape, waterfalls at their best, but beach activities are limited |
# | **Oct – Nov** | Post‑monsoon, pleasant, less rain | Emerging shoulder season – good balance of price and weather |
#
# **July falls squarely in the monsoon window.** Expect frequent, sometimes heavy, showers in the afternoon and early evening, high humidity, and a chance of occasional thunderstorms. The sea can be rough, and many beach‑side shacks and water‑sports operators close for safety.
#
# ### Why you might still want to go in July
# - **Lower prices** – accommodation, flights, and many tours drop 30‑50 % compared with the peak winter months.
# - **Fewer crowds** – you’ll have the beaches and historic sites almost to yourself.
# - **Lush scenery** – the Western Ghats turn a vivid green; waterfalls (e.g., **Dudhsagar**, **Arvalem**) are at their most spectacular.
# - **Monsoon Festival** – Goa celebrates the rains with cultural events, music, food stalls, and traditional dances, usually held in early to mid‑July.
#
# ### Things to keep in mind
# 1. **Beach activities** – swimming, surfing, and water‑sports are limited; many beach bars and restaurants shut down during heavy rain.
# 2. **Travel logistics** – some rural roads can become slippery; plan extra travel time.
# 3. **Health** – bring mosquito repellent (monsoon brings more mosquitoes) and stay hydrated.
# 4. **Indoor attractions** – this is a great time to explore Old Goa’s churches, spice farms, museums, and the vibrant night‑life in Panaji or the **Anjuna Flea Market** (still open on Sundays).
#
# ### Bottom line
# - **If your priority is sun‑bathing, swimming, and lively beach parties, July is *not* the ideal time.**
# - **If you’re looking for a quiet, budget‑friendly getaway, love green landscapes, want to see waterfalls at their peak, and don’t mind occasional rain, July can be a rewarding time to visit.**
#
# ---
#
# ### Quick tip for planning
# - **Pack:** lightweight rain jacket, quick‑dry clothing, waterproof shoes, sunscreen (the sun can still be strong between showers), and a good umbrella.
# - **Check:** the 3‑day weather forecast before heading out each day; mornings are often clear, with rain developing later.
#
# Enjoy your trip—whether you decide to soak up the monsoon magic or wait for the cooler, drier months! 🌴☔️✈️
