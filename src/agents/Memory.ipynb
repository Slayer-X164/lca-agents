# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv()

model = init_chat_model(
  model="openai/gpt-oss-120b",
  model_provider="groq"
)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

config = {"configurable":{"thread_id":"chat-01"}}

agent = create_agent(
  model=model,
  checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

while(True):
  userInput = input("Ask Anything: ")
  if userInput.lower() == "exit":
    break
  
  query = HumanMessage(content=userInput)
  response = agent.invoke(
    {"messages":[query]},
    config
  )
  print(response["messages"][-1].content)
# Out:
# Hi Sidd! Nice to meet you. How can I assist you today?
# You introduced yourself as **Siddhesh**, and you said I can call you **Sidd**.
